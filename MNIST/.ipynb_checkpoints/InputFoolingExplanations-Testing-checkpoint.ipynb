# %%
import torch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.nn import functional as F
import torchvision.datasets as datasets

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# *** I need to actually do something more sophisicated with normalization to ensure that these
# inputs are normalized in the same waya as the ones we trained on, but Torch seems
# a bit complicated to me on this front so I am ignoring it for now :) 

device = torch.device("cpu")
mnist_trainset = datasets.MNIST(root='./Datasets', train=True, download=True, transform=None)
mnist_testset = datasets.MNIST(root='./Datasets', train=False, download=True, transform=None)

import sys
sys.path.append("..")
import XAIArchitectures
import GradCertModule
import pytorch_lightning as pl
from pl_examples.basic_examples.mnist_datamodule import MNISTDataModule


ALPHA = 1.0            # Regularization Parameter (Weights the Reg. Term)
EPSILON = 0.05          # Input Peturbation Budget at Training Time
GAMMA = 0.1            # Model Peturbation Budget at Training Time 
                        #(Changed to proportional budget rather than absolute)
    
LEARN_RATE = 0.001      # Learning Rate Hyperparameter
HIDDEN_DIM = 100       # Hidden Neurons Hyperparameter
HIDDEN_LAY = 1         # Hidden Layers Hyperparameter
MAX_EPOCHS = 10

EPSILON_LINEAR = True   # Put Epsilon on a Linear Schedule?
GAMMA_LINEAR = True     # Put Gamma on a Linear Schedule?

# %%
model = XAIArchitectures.FullyConnected()

SCHEDULED = EPSILON_LINEAR or GAMMA_LINEAR 
#DeepMindSmall_e=0.0_g=0.0_a=0.0_s=True.ckpt
MODEL_ID = "FCN_e=%s_g=%s_a=%s_s=%s"%(EPSILON, GAMMA, ALPHA, SCHEDULED)
#MODEL_ID = "DeepMindSmall_e=%s_g=%s_h=%s_l=%s_a=%s_s=%s"%(EPSILON, GAMMA, HIDDEN_DIM, HIDDEN_LAY, ALPHA, SCHEDULED)   
ckpt = torch.load("FCN_Models/%s.ckpt"%(MODEL_ID))

optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
checkpoint = torch.load("FCN_Models/%s.ckpt"%(MODEL_ID))
for key in checkpoint:
    print(key)
model.load_state_dict(torch.load('FCN_Models/%s.pt'%(MODEL_ID)))
# Out:
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# <All keys matched successfully>

# %%
print(mnist_testset.data.shape)
model.inputfooling_ON()
acc = 0
for i in range(1000):
    data = np.asarray(mnist_testset[i][0]).reshape(1,28,28)/255.0
    target = torch.Tensor([mnist_testset[i][1]]).type(torch.LongTensor)
    #model(torch.Tensor(data[None, :]))
    out = torch.argmax(model(torch.Tensor([data])))
    if(target == out):
        acc += 1
print(acc/1000)
# Out:
# torch.Size([10000, 28, 28])
# 0.749
# /Users/matthewwicker/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /Users/distiller/project/pytorch/torch/csrc/utils/tensor_new.cpp:210.)

# %%
from GradCertModule import run_mnist_attack
from GradCertModule import run_model_attack

# %%
x = np.asarray(mnist_testset[2][0]).reshape(1,28,28)/255.0
x = torch.Tensor(x)

out, cls = model.classify(x)
grad = GradCertModule.InputGrad(model, torch.Tensor(x.detach().numpy().reshape(1,28*28)), 
                                target=cls)
plt.imshow(grad.detach().numpy().reshape(28,28), cmap="coolwarm")
plt.colorbar()
plt.show()

# %%
fool_i, fool_j = 4, 4
#success, x_adv, grad_adv, targex = run_mnist_attack(model, x, target = [5,5], epsilon=0.1, iterations=500, lr=0.01)
success, x_adv, grad_adv, targex = run_model_attack(model, x, target = [fool_i, fool_i], gamma=0.5, iterations=50, lr=0.01)

print(success)
# Out:
# False
# ../GradCertModule.py:768: UserWarning: Using a target size (torch.Size([28, 28])) that is different to the input size (torch.Size([1, 1, 28, 28])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss_expl = F.mse_loss(grad_adv, target_expl)

# %%
#out, cls = model.classify(x_adv)
#grad = GradCertModule.InputGrad(model, torch.Tensor(x_adv.detach().numpy().reshape(1,28*28)), 
#                                target=cls)
#plt.imshow(grad.detach().numpy().reshape(28,28))
#plt.show()

# %%
plt.imshow(np.squeeze(targex.detach().numpy()), cmap="coolwarm")
plt.colorbar()
plt.show()

# %%
#plt.imshow(np.squeeze(x_adv.detach().numpy()))
#plt.show()

# %%
grad_adv = grad_adv.detach().numpy().reshape(28,28)

# %%
#print(ROBUST_COUNT)
import matplotlib
import matplotlib.pyplot as plt

plt.imshow(grad_adv, cmap="coolwarm")
plt.colorbar()
plt.show()
print(np.argmax(grad_adv)/28)
print(np.argmax(grad_adv)%28)

#import os
#if not os.path.exists(directory):
#    os.makedirs(directory)
# Out:
# 13.5
# 14

# %%
from tqdm import trange
import os
"""
directory = "figuredata_robust"
if not os.path.exists(directory):
    os.makedirs(directory)

grad = GradCertModule.InputGrad(model, torch.Tensor(x.detach().numpy().reshape(1,28*28)), 
                                target=cls)
grad = grad.detach().numpy().reshape(28,28)
np.save("%s/%s_%s"%(directory, -1, -1), grad)  

for fool_i in trange(4,24):
    for fool_j in range(4,24):
        model.load_state_dict(torch.load('FCN_Models/%s.pt'%(MODEL_ID)))
        success, x_adv, grad_adv, targex = run_model_attack(model, x, target = [fool_i, fool_j], gamma=0.5, iterations=100, lr=0.01)
        #print(grad_adv)
        grad_adv = grad_adv.detach().numpy().reshape(28,28)
        np.save("%s/%s_%s"%(directory, fool_i, fool_j), grad_adv)
    #print(fool_i)
"""
# Out:
# '\ndirectory = "figuredata_robust"\nif not os.path.exists(directory):\n    os.makedirs(directory)\n\ngrad = GradCertModule.InputGrad(model, torch.Tensor(x.detach().numpy().reshape(1,28*28)), \n                                target=cls)\ngrad = grad.detach().numpy().reshape(28,28)\nnp.save("%s/%s_%s"%(directory, -1, -1), grad)  \n\nfor fool_i in trange(4,24):\n    for fool_j in range(4,24):\n        model.load_state_dict(torch.load(\'FCN_Models/%s.pt\'%(MODEL_ID)))\n        success, x_adv, grad_adv, targex = run_model_attack(model, x, target = [fool_i, fool_j], gamma=0.5, iterations=100, lr=0.01)\n        #print(grad_adv)\n        grad_adv = grad_adv.detach().numpy().reshape(28,28)\n        np.save("%s/%s_%s"%(directory, fool_i, fool_j), grad_adv)\n    #print(fool_i)\n'

# %%
plt.imshow(np.squeeze(x.detach().numpy()), cmap='gray_r')
plt.show()

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

#prefix = "robust"
prefix = "vulnerable"

def f(A, B):
    A = max(4, A); A = min(19, A)
    B = max(4, B); B = min(19, B)
    #A -= A%2
    #B -= B%2
    print(A, B)
    a = np.load("figuredata_%s/%s_%s.npy"%(prefix, A, B))
    #a = np.abs(a)
    #print(a)
    return a
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
image = ax.imshow(f(A=1, B=1), animated=True, cmap="coolwarm")
plt.show()
def update(A = 1, B = 0):
    image.set_array(f(A,B))
    fig.canvas.draw_idle()
    
interact(update, A = 20, B = 20);
# Out:
# <img src="data:image/png;base64,..." width="640">
# 4 4
# interactive(children=(IntSlider(value=20, description='A', max=60, min=-20), IntSlider(value=20, description='…

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

prefix = "robust"
#prefix = "vulnerable"

def f(A, B):
    if(A < 0 and B < 0):
        A = -1; B = -1
    else:
        A = max(4, A); A = min(19, A)
        B = max(4, B); B = min(19, B)
        #A -= A%2
        #B -= B%2
    a = np.load("figuredata_%s/%s_%s.npy"%(prefix, A, B))
    #a = np.abs(a)
    #print(a)
    return a
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
image = ax.imshow(f(A=1, B=1), animated=True, cmap="coolwarm")
plt.show()
def update(A = 1, B = 0):
    image.set_array(f(A,B))
    fig.canvas.draw_idle()
    
interact(update, A = 16, B = 16);
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=16, description='A', max=48, min=-16), IntSlider(value=16, description='…

# %%
"""
ROBUST_COUNT = 0
INDEX = 0
for INDEX in range(1):
    x = np.asarray(mnist_testset[INDEX][0]).reshape(1,28,28)/255.0
    x = torch.Tensor(x)
    success = False
    for targ in range(1):
        success, x_adv, grad_adv, targex = run_mnist_attack(model, x, target = [5,5], epsilon=1.0, iterations=500, lr=0.01)         
        #success, x_adv, grad_adv = run_model_attack(model, x, target = [0,0], epsilon=0.2, iterations=500, lr=0.01)
        if(success == True):
            break
    if(success == True):
        print("vulnerable")
        continue
    else:
        ROBUST_COUNT += 1
        print("Robust")
"""
# Out:
# '\nROBUST_COUNT = 0\nINDEX = 0\nfor INDEX in range(1):\n    x = np.asarray(mnist_testset[INDEX][0]).reshape(1,28,28)/255.0\n    x = torch.Tensor(x)\n    success = False\n    for targ in range(1):\n        success, x_adv, grad_adv, targex = run_mnist_attack(model, x, target = [5,5], epsilon=1.0, iterations=500, lr=0.01)         \n        #success, x_adv, grad_adv = run_model_attack(model, x, target = [0,0], epsilon=0.2, iterations=500, lr=0.01)\n        if(success == True):\n            break\n    if(success == True):\n        print("vulnerable")\n        continue\n    else:\n        ROBUST_COUNT += 1\n        print("Robust")\n'
