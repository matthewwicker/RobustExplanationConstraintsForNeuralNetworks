# %%
import torch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.nn import functional as F
import torchvision.datasets as datasets

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# *** I need to actually do something more sophisicated with normalization to ensure that these
# inputs are normalized in the same waya as the ones we trained on, but Torch seems
# a bit complicated to me on this front so I am ignoring it for now :) 

device = torch.device("cpu")
mnist_trainset = datasets.MNIST(root='./Datasets', train=True, download=True, transform=None)
mnist_testset = datasets.MNIST(root='./Datasets', train=False, download=True, transform=None)

import sys
sys.path.append("..")
import XAIArchitectures
import GradCertModule
import pytorch_lightning as pl
from pl_examples.basic_examples.mnist_datamodule import MNISTDataModule


ALPHA = 0.00            # Regularization Parameter (Weights the Reg. Term)
EPSILON = 0.0          # Input Peturbation Budget at Training Time
GAMMA = 0.00             # Model Peturbation Budget at Training Time 
                        #(Changed to proportional budget rather than absolute)
    
LEARN_RATE = 0.001      # Learning Rate Hyperparameter
HIDDEN_DIM = 100       # Hidden Neurons Hyperparameter
HIDDEN_LAY = 1         # Hidden Layers Hyperparameter
MAX_EPOCHS = 10

EPSILON_LINEAR = True   # Put Epsilon on a Linear Schedule?
GAMMA_LINEAR = True     # Put Gamma on a Linear Schedule?

# %%
model = XAIArchitectures.FullyConnected()
# Out:
# SET MODE TO:  GRAD

# %%
def load_model(model, gamma, epsilon):
    SCHEDULED = EPSILON_LINEAR or GAMMA_LINEAR 
    #DeepMindSmall_e=0.0_g=0.0_a=0.0_s=True.ckpt
    MODEL_ID = "FCN_e=%s_g=%s_a=%s_s=%s"%(epsilon, gamma, ALPHA, SCHEDULED)
    #MODEL_ID = "DeepMindSmall_e=%s_g=%s_h=%s_l=%s_a=%s_s=%s"%(EPSILON, GAMMA, HIDDEN_DIM, HIDDEN_LAY, ALPHA, SCHEDULED)   
    ckpt = torch.load("FCN_Models/%s.ckpt"%(MODEL_ID))

    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
    checkpoint = torch.load("FCN_Models/%s.ckpt"%(MODEL_ID))
    for key in checkpoint:
        print(key)
    model.load_state_dict(torch.load('FCN_Models/%s.pt'%(MODEL_ID)))

    
load_model(model, 0.0, 0.0)
# Out:
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters

# %%
def estimate_acc(model):
    acc = 0
    for i in range(1000):
        data = np.asarray(mnist_testset[i][0]).reshape(1,28,28)/255.0
        target = torch.Tensor([mnist_testset[i][1]]).type(torch.LongTensor)
        model(torch.Tensor(data[None, :]))
        out = torch.argmax(model(torch.Tensor([data])))
        if(target == out):
            acc += 1
    return acc/1000

estimate_acc(model)
# Out:
# /Users/matthewwicker/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1659484744261/work/torch/csrc/utils/tensor_new.cpp:204.)
#   import sys
# 0.973

# %%
def estimate_gradcert(model):
    val = 0
    for i in range(1000):
        data = np.asarray(mnist_testset[i][0]).reshape(1,28*28)/255.0
        target = torch.Tensor([mnist_testset[i][1]]).type(torch.LongTensor)
        data = torch.Tensor(data)
        min_grad, max_grad = GradCertModule.GradCertBounds(model, data, target, 0.1, 0.1)
        min_grad, max_grad = min_grad.detach().numpy(), max_grad.detach().numpy()
        val += np.mean(max_grad)
    return val/1000

estimate_gradcert(model)
# Out:
# 1691.0695842285156

# %%
zero_acc = 0.973
zero_grad = 6.126

# %%
ALPHA = 0.5
acc_grid = np.zeros((3,3))
i = 0
for e in [0.01, 0.025, 0.05]: #, 0.1]:
    j = 0
    for g in [0.01, 0.025, 0.05]: #, 0.1]:
        load_model(model, g, e)
        acc = estimate_acc(model)
        print(acc)
        acc_grid[i][j] = acc
        j+=1
    i += 1
# Out:
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.946
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.945
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.927
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.917
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.909
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.894
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.871
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.858
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.841

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_context('poster')
plt.figure(figsize=(10, 10), dpi=120)

ax = sns.heatmap(acc_grid, annot=True, cmap="Blues")
ax.set_xticklabels([0.01, 0.025, 0.05])
ax.set_yticklabels([0.01, 0.025, 0.05])
ax.set_xlabel(r'$\epsilon_t$')
ax.set_ylabel(r'$\gamma_t$')
ax.set_title('Test Set Accuracy')
# Out:
# Text(0.5, 1.0, 'Test Set Accuracy')

# %%
ALPHA = 0.5
val_grid = np.zeros((3,3))
i = 0
for e in [0.01, 0.025, 0.05]: #, 0.1]:
    j = 0
    for g in [0.01, 0.025, 0.05]: #, 0.1]:
        load_model(model, e, g)
        val = estimate_gradcert(model)
        print(val)
        val_grid[i][j] = val
        j+=1
    i += 1
# Out:
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 2.593076400092803
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.4481950836740434
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.18807131874593325
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 1.7168875114079565
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.6334672717349604
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.1573845583976363
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 1.4016258704541251
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.34267473719781266
# epoch
# global_step
# pytorch-lightning_version
# state_dict
# callbacks
# optimizer_states
# lr_schedulers
# hparams_name
# hyper_parameters
# 0.15274422750098166

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_context('poster')
plt.figure(figsize=(10, 10), dpi=120)
ax = sns.heatmap(val_grid, annot=True, cmap="Reds", vmax=1.0)
ax.set_xticklabels([0.01, 0.025, 0.05])
ax.set_yticklabels([0.01, 0.025, 0.05])
ax.set_xlabel(r'$\epsilon_t$')
ax.set_ylabel(r'$\gamma_t$')
ax.set_title('Cert. Bound Difference')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wk/dw_2kpzx6yggmhdyw5k5gj200000gn/T/ipykernel_16579/4251152194.py in <module>
#       5 plt.figure(figsize=(10, 10), dpi=120)
#       6 ax = sns.heatmap(val_grid, annot=True, cmap="Reds", vmax=1.0)
# ----> 7 ax.set_xticklabels([0.01, 0.025, 0.05])
#       8 ax.set_yticklabels([0.01, 0.025, 0.05])
#       9 ax.set_xlabel(r'$\epsilon_t$')
#
# ~/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# ~/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796         if fontdict is not None:
#    1797             kwargs.update(fontdict)
# -> 1798         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1799
#    1800     def _set_tick_locations(self, ticks, *, minor=False):
#
# ~/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1719             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1720                 raise ValueError(
# -> 1721                     "The number of FixedLocator locations"
#    1722                     f" ({len(locator.locs)}), usually from a call to"
#    1723                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (5), usually from a call to set_ticks, does not match the number of ticklabels (3).

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_context('poster')
plt.figure(figsize=(10, 10), dpi=120)
ax = plt.gca()

threshold = 0.25
v_grid = val_grid 
im = ax.imshow(v_grid, cmap=plt.cm.OrRd, interpolation='none', vmax=threshold)

# Loop over data dimensions and create text annotations.
for i in range(len(v_grid)):
    for j in range(len(v_grid[0])):
        text = ax.text(j, i, "%.2f" %v_grid[i, j],
                       ha="center", va="center", color="w")

#ax = sns.heatmap(v_grid, annot=True, cmap="Reds")
ax.set_xticklabels([0.0, 0.0, 0.01, 0.025, 0.05, 0.1])
ax.set_yticklabels([0.0, 0.0 ,0.01, 0.025, 0.05, 0.1])
ax.set_xlabel(r'$\epsilon_t$') 
ax.set_ylabel(r'$\gamma_t$')
ax.set_title('Avg. Bound Difference')
# Out:
# /Users/matthewwicker/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/matthewwicker/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
# Text(0.5, 1.0, 'Avg. Bound Difference')

# %%
import numpy as np
import matplotlib.pyplot as plt

threshold = 0.8
data = np.random.random((10,10))

fig, ax = plt.subplots()
im = ax.imshow(data, cmap=plt.cm.hot, interpolation='none', vmax=threshold)
cbar = fig.colorbar(im, extend='max')
cbar.cmap.set_over('green')

plt.show()
# Out:
# /Users/matthewwicker/opt/anaconda3/envs/XAIenvironment/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("hot").copy()
#   # Remove the CWD from sys.path while we load stuff.

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(['darkblue','darkred'])
plt.figure(figsize=(6, 4), dpi=120)

ax = sns.heatmap([[0.973, 6.126]], annot=True, cmap=cmap, fmt=".2f")

ax.set_xticklabels(["Acc.", "Bound Diff."])
ax.set_yticklabels([" "])
ax.set_xlabel(r' ')
ax.set_ylabel(r' ')
ax.set_title('Normally Trained NN')
# Out:
# Text(0.5, 1.0, 'Normally Trained NN')

# %%
from GradCertModule import run_mnist_attack
from tqdm import trange
def estimate_attack_robustness(model_to_test, epsilon=0.45):
    ROBUST_COUNT = 0
    INDEX = 0
    for INDEX in trange(100):
        x = np.asarray(mnist_testset[INDEX][0]).reshape(1,28,28)/255.0
        x = torch.Tensor(x)
        success = False
        #for targ in range(6):
        #    success, x_adv, grad_adv = run_mnist_attack(model_to_test, x, target = targ, epsilon=epsilon, iterations=50, lr=epsilon/50)
        #    if(success == True):
        #        break
        success, x_adv, grad_adv = run_mnist_attack(model_to_test, x, target = "corners", epsilon=epsilon, iterations=50, lr=0.05)
        if(success == True):
            #print("vulnerable")
            continue
        else:
            ROBUST_COUNT += 1
            #print("Robust")
    return ROBUST_COUNT/100

# %%
ALPHA = 0.5
val_grid = np.zeros((5,5))
i = 0
for e in [0.0, 0.01, 0.025, 0.05, 0.1]:
    j = 0
    for g in [0.0, 0.01, 0.025, 0.05, 0.1]:
        load_model(model, e, g)
        model.inputfooling_ON()
        val = estimate_attack_robustness(model)
        print(val)
        val_grid[i][j] = val
        j+=1
| 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015526837669312954:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015526837669312954:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.00155275606084615:  82%|█████████████████████████████████████▋        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.00155275606084615:  82%|█████████████████████████████████████▋        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.001552826026454568:  82%|████████████████████████████████████▉        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.001552826026454568:  82%|████████████████████████████████████▉        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015528872609138489:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015528872609138489:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015529491938650608:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015529491938650608:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015530111268162727:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015530111268162727:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015530730597674847:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.0015530730597674847:  82%|████████████████████████████████████        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.001553134759888053:  82%|████████████████████████████████████▉        | 41/50 [00:00<00:00, 125.09it/s]
# Loss: -0.001553134759888053: 100%|█████████████████████████████████████████████| 50/50 [00:00<00:00, 126.64it/s]
#   0%|                                                                                   | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wk/dw_2kpzx6yggmhdyw5k5gj200000gn/T/ipykernel_16579/1220379718.py in <module>
#       7         load_model(model, e, g)
#       8         model.inputfooling_ON()
# ----> 9         val = estimate_attack_robustness(model)
#      10         print(val)
#      11         val_grid[i][j] = val
#
# /var/folders/wk/dw_2kpzx6yggmhdyw5k5gj200000gn/T/ipykernel_16579/989534687.py in estimate_attack_robustness(model_to_test, epsilon)
#      12         #    if(success == True):
#      13         #        break
# ---> 14         success, x_adv, grad_adv = run_mnist_attack(model_to_test, x, target = "corners", epsilon=epsilon, iterations=50, lr=0.05)
#      15         if(success == True):
#      16             #print("vulnerable")
#
# ValueError: too many values to unpack (expected 3)

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_context('poster')
plt.figure(figsize=(10, 10), dpi=120)

ax = sns.heatmap(val_grid, annot=True, cmap="Purples", vmax=1.0)
ax.set_xticklabels([0.0, 0.01, 0.025, 0.05, 0.1])
ax.set_yticklabels([0.0, 0.01, 0.025, 0.05, 0.1])
ax.set_xlabel(r'$\epsilon_t$')
ax.set_ylabel(r'$\gamma_t$')
ax.set_title(r'Attack Robustness (Location, $\epsilon=0.35$)')

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_context('poster')
plt.figure(figsize=(10, 10), dpi=120)
ax = plt.gca()

threshold = -0.3
v_grid = val_grid 
im = ax.imshow(v_grid, cmap=plt.cm.Purples, interpolation='none', vmin=threshold, vmax=1.3)

# Loop over data dimensions and create text annotations.
for i in range(len(v_grid)):
    for j in range(len(v_grid[0])):
        text = ax.text(j, i, "%.2f" %v_grid[i, j],
                       ha="center", va="center", color="w")

#ax = sns.heatmap(v_grid, annot=True, cmap="Reds")
ax.set_xticklabels([0.0, 0.0, 0.01, 0.025, 0.05, 0.1])
ax.set_yticklabels([0.0, 0.0 ,0.01, 0.025, 0.05, 0.1])
ax.set_xlabel(r'$\epsilon_t$') 
ax.set_ylabel(r'$\gamma_t$')
ax.set_title(r'Attack Robustness (Location, $\epsilon=0.35$)')
